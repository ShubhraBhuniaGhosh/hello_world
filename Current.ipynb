# %% [markdown]
# <a href="https://colab.research.google.com/github/ShubhraBhuniaGhosh/hello_world/blob/master/Current.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Load dataset from - https://covid.ourworldindata.org/data/owid-covid-data.csv

# %%
import pandas as pd

# %%
from google.colab import files
import io
uploaded = files.upload()
df = pd.read_csv(io.BytesIO(uploaded['owid-covid-data.csv']))
# Out:
#      <input type="file" id="files-a324762a-2b51-4437-ac64-5823c445ffa8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a324762a-2b51-4437-ac64-5823c445ffa8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-3aa904f16186> in <module>()
#       1 from google.colab import files
#       2 import io
# ----> 3 uploaded = files.upload()
#       4 df = pd.read_csv(io.BytesIO(uploaded['owid-covid-data.csv']))
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      67   result = _output.eval_js(
# ...

# %%
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'tests_units',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy'],
#       dtype='object')

# %%
df.shape
# Out:
# (31705, 34)

# %%
df.head(5)
# Out:
#   iso_code continent  ... hospital_beds_per_thousand life_expectancy
# 0      AFG      Asia  ...                        0.5           64.83
# 1      AFG      Asia  ...                        0.5           64.83
# 2      AFG      Asia  ...                        0.5           64.83
# 3      AFG      Asia  ...                        0.5           64.83
# 4      AFG      Asia  ...                        0.5           64.83
#
# [5 rows x 34 columns]

# %% [markdown]
# #2. Subset only those rows that have “India” in the “location” column(This subsetted dataframe has to be used for modelling)

# %%
data = df[df.location == 'India'].copy()

# %%
data.head(5)

# %%
data.location.unique()
# Out:
# array(['India'], dtype=object)

# %%
data.shape
# Out:
# (203, 34)

# %% [markdown]
# #3. Univariate Analysis:
#
# ## a. Draw histograms of each numerical variable
#
# ## b. Find mean, median and mode of each column

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter

# %%
column=['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
       'total_deaths', 'new_deaths', 'total_cases_per_million',
       'new_cases_per_million', 'total_deaths_per_million',
       'new_deaths_per_million', 'total_tests', 'new_tests',
       'total_tests_per_thousand', 'new_tests_per_thousand',
       'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'tests_units',
       'stringency_index', 'population', 'population_density', 'median_age',
       'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
       'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
       'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
       'life_expectancy']
column = sorted(column)
#print(column)
for i in column:
 print(i,end="\n\n\n")
 print(data[i].unique(), end="\n\n\n")
# Out:
# aged_65_older
#
#
# [5.989]
#
#
# aged_70_older
#
#
# [3.414]
#
#
# cardiovasc_death_rate
#
#
# [282.28]
#
#
# continent
#
#
# ['Asia']
#
#
# date
#
#
# ['2019-12-31' '2020-01-01' '2020-01-02' '2020-01-03' '2020-01-04'
#  '2020-01-05' '2020-01-06' '2020-01-07' '2020-01-08' '2020-01-09'
#  '2020-01-10' '2020-01-11' '2020-01-12' '2020-01-13' '2020-01-14'
#  '2020-01-15' '2020-01-16' '2020-01-17' '2020-01-18' '2020-01-19'
#  '2020-01-20' '2020-01-21' '2020-01-22' '2020-01-23' '2020-01-24'
#  '2020-01-25' '2020-01-26' '2020-01-27' '2020-01-28' '2020-01-29'
#  '2020-01-30' '2020-01-31' '2020-02-01' '2020-02-02' '2020-02-03'
#  '2020-02-04' '2020-02-05' '2020-02-06' '2020-02-07' '2020-02-08'
#  '2020-02-09' '2020-02-10' '2020-02-11' '2020-02-12' '2020-02-13'
#  '2020-02-14' '2020-02-15' '2020-02-16' '2020-02-17' '2020-02-18'
#  '2020-02-19' '2020-02-20' '2020-02-21' '2020-02-22' '2020-02-23'
#  '2020-02-24' '2020-02-25' '2020-02-26' '2020-02-27' '2020-02-28'
# ...

# %%
data.rename(columns={'aged_65_older'  :  'Aged over 65' , 'aged_70_older'  :  'Aged over 70' , 'cardiovasc_death_rate'  :  'Cardiovasc Death Rate' , 'diabetes_prevalence'  :  'Diabetes Prevalence' , 'extreme_poverty'  :  'Extreme Poverty' , 'female_smokers'  :  'Female Smokers' , 'gdp_per_capita'  :  'GDP Per Capita' , 'handwashing_facilities'  :  'Handwashing Facilities' , 'hospital_beds_per_thousand'  :  'Hospital Beds Per Thousand' , 'life_expectancy'  :  'Life Expectancy' , 'male_smokers'  :  'Male Smokers' , 'median_age'  :  'Median Age' , 'new_cases'  :  'New Cases' , 'new_cases_per_million'  :  'New Cases Per Million' , 'new_deaths'  :  'New Deaths' , 'new_deaths_per_million'  :  'New Deaths Per Million' , 'new_tests'  :  'New Tests' , 'new_tests_per_thousand'  :  'New Tests Per Thousand' , 'new_tests_smoothed'  :  'New Tests Smoothed' , 'new_tests_smoothed_per_thousand'  :  'New Tests Smoothed Per Thousand' , 'population'  :  'Population' , 'population_density'  :  'Population Density' , 'stringency_index'  :  'Stringency Index' , 'total_cases'  :  'Total Cases' , 'total_cases_per_million'  :  'Total Cases Per Million' , 'total_deaths'  :  'Total Deaths' , 'total_deaths_per_million'  :  'Total Deaths Per Million' , 'total_tests'  :  'Total Tests' , 'total_tests_per_thousand'  :  'Total Tests Per Thousand'}, inplace=True)

# %%
ax = data.hist(grid=False, figsize=(20,64) ,layout = (10,3))
i = 0
for row in ax:
  for x in row:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    #Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Set x-axis label
    #x.set_xlabel("Session Duration (Seconds)", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("No Of Days From 31 Dec to 22 Jul", labelpad=20, weight='bold', size=12)

    # Format y-axis label
    x.yaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))

# %%
data.mean(axis = 0)
# Out:
# Total Cases                        1.553296e+05
# New Cases                          5.690596e+03
# Total Deaths                       4.396640e+03
# New Deaths                         1.383448e+02
# Total Cases Per Million            1.125573e+02
# New Cases Per Million              4.123611e+00
# Total Deaths Per Million           3.185966e+00
# New Deaths Per Million             1.002315e-01
# Total Tests                        4.005175e+06
# New Tests                          1.230359e+05
# Total Tests Per Thousand           2.902325e+00
# New Tests Per Thousand             8.915315e-02
# New Tests Smoothed                 1.045399e+05
# New Tests Smoothed Per Thousand    7.575410e-02
# Stringency Index                   5.530901e+01
# Population                         1.380004e+09
# Population Density                 4.504190e+02
# Median Age                         2.820000e+01
# Aged over 65                       5.989000e+00
# Aged over 70                       3.414000e+00
# ...

# %%
data.median(axis = 0)
# Out:
# Total Cases                        7.447000e+03
# New Cases                          7.960000e+02
# Total Deaths                       2.390000e+02
# New Deaths                         3.200000e+01
# Total Cases Per Million            5.396000e+00
# New Cases Per Million              5.770000e-01
# Total Deaths Per Million           1.730000e-01
# New Deaths Per Million             2.300000e-02
# Total Tests                        2.719434e+06
# New Tests                          1.080480e+05
# Total Tests Per Thousand           1.971000e+00
# New Tests Per Thousand             7.800000e-02
# New Tests Smoothed                 9.305900e+04
# New Tests Smoothed Per Thousand    6.750000e-02
# Stringency Index                   7.546000e+01
# Population                         1.380004e+09
# Population Density                 4.504190e+02
# Median Age                         2.820000e+01
# Aged over 65                       5.989000e+00
# Aged over 70                       3.414000e+00
# ...

# %%
data.mode().head(1)
# Out:
#   iso_code continent  ... Hospital Beds Per Thousand Life Expectancy
# 0      IND      Asia  ...                       0.53           69.66
#
# [1 rows x 34 columns]

# %% [markdown]
# # 4. Bivariate Analysis:
#
# ##a. Draw scatter plots of each numerical column versus one another
#
# ##b. Draw line plots of each numerical column versus one another

# %%
y_title = list(data.columns)
y_title = y_title[4:]
y_title.pop(y_title.index('tests_units'))
# Out:
# 'tests_units'

# %%
import matplotlib.pyplot as plt
x = pd.DataFrame([i for i in range(1,data.shape[0]+1)])
for i in y_title:
  y = pd.DataFrame(data[i]).copy()
  plt.figure(figsize=(4, 4), dpi=80)
  plt.scatter(x, y)
  plt.xlabel("No Of date", fontsize=10)
  plt.ylabel(i, fontsize=10)
  plt.show()

# %%
import matplotlib.pyplot as plt
for i in y_title:
  data.plot(x='date' , y=i , kind = 'line', figsize=(24,8))

# %% [markdown]
# 5. Handle Missing values:
#
# a. If there are null values in numerical column, replace the null values by the mean of that column
#
# b. If there are null values in categorical column, replace the null values by the mode of that column
#
# c. If more than 50%the values in a column are null, then drop that entire column

# %%
data.isnull().sum()
# Out:
# iso_code                            0
# continent                           0
# location                            0
# date                                0
# Total Cases                         0
# New Cases                           0
# Total Deaths                        0
# New Deaths                          0
# Total Cases Per Million             0
# New Cases Per Million               0
# Total Deaths Per Million            0
# New Deaths Per Million              0
# Total Tests                        86
# New Tests                          92
# Total Tests Per Thousand           86
# New Tests Per Thousand             92
# New Tests Smoothed                 81
# New Tests Smoothed Per Thousand    81
# tests_units                        74
# Stringency Index                   12
# Population                          0
# Population Density                  0
# Median Age                          0
# Aged over 65                        0
# Aged over 70                        0
# ...

# %%
data["total_tests"].fillna(data.total_tests.mean(), inplace = True)
data["new_tests"].fillna(data.new_tests.mean(), inplace = True)
data["total_tests_per_thousand"].fillna(data.total_tests_per_thousand.mean(), inplace = True)
data["new_tests_per_thousand"].fillna(data.new_tests_per_thousand.mean(), inplace = True)
data["new_tests_smoothed"].fillna(data.new_tests_smoothed.mean(), inplace = True)
data["new_tests_smoothed_per_thousand"].fillna(data.new_tests_smoothed_per_thousand.mean(), inplace = True)
data["stringency_index"].fillna(data.stringency_index.mean(), inplace = True)

# %%
data.isnull().sum()

# %% [markdown]
# 6. Convert date column to ordinal
#
# a. Code:
#
# import datetime as dt
#
# df["date"]=pd.to_datetime(df["date"])
#
# df["date"]=df["date"].map(dt.datetime.toordinal)

# %%
import datetime as dt

df["date"]=pd.to_datetime(df["date"])

df["date"]=df["date"].map(dt.datetime.toordinal)

# %% [markdown]
# 7. Drop all categorical columns

# %%
data.head(5)
# Out:
#       iso_code continent  ... hospital_beds_per_thousand life_expectancy
# 13249      IND      Asia  ...                       0.53           69.66
# 13250      IND      Asia  ...                       0.53           69.66
# 13251      IND      Asia  ...                       0.53           69.66
# 13252      IND      Asia  ...                       0.53           69.66
# 13253      IND      Asia  ...                       0.53           69.66
#
# [5 rows x 34 columns]

# %%
data.drop(columns=['iso_code'], inplace=True)                                       
data.drop(columns=['continent'], inplace=True)                                       
data.drop(columns=['location'], inplace=True)                                       
data.drop(columns=['tests_units'], inplace=True)

# %% [markdown]
# 8. Select “total_cases” column as the target variable

# %%
x =

# %% [markdown]
# 9. Select the other columns as the features(the “date” column has to be in the features)

# %% [markdown]
# 10. Perform train-test split

# %%
#Train Test Split on the Train dataset
seed = 15
test_size = 0.3
X_train, X_val, Y_train, Y_val = train_test_split(train_x, train_y, test_size = test_size, random_state = seed)

# %% [markdown]
# 11. Modelling:
# a. Linear Regression
# b. Random Forest Regressor

# %% [markdown]
# 12. Get accuracy

# %% [markdown]
# 13. Predict Total case for a new date
